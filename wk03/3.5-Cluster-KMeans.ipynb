# %%
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 3.5.1 生成数据：2个特征值、3个类别

# %%
X,y = datasets.make_blobs(n_samples=500,centers=4,n_features=2)

# %%
X.shape,y.shape
# Out:
# ((500, 2), (500,))

# %%
plt.scatter(x=X[:,0],y=X[:,1],c=y)

# %%
# 3.5.2 kmeans聚类分析

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %%
kms = KMeans(n_clusters=4)
kms.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kms.cluster_centers_
# Out:
# array([[-0.57806947,  3.48698598],
#        [-7.42186031,  5.44352732],
#        [-2.03414595,  5.04032477],
#        [-7.87823576,  7.81477176]])

# %%
kms.labels_
# Out:
# array([3, 3, 0, 1, 3, 1, 2, 0, 0, 1, 0, 2, 1, 1, 1, 2, 3, 2, 0, 0, 3, 2,
#        2, 1, 3, 3, 1, 1, 0, 0, 0, 3, 0, 2, 3, 2, 0, 2, 3, 3, 3, 3, 3, 2,
#        2, 3, 0, 2, 1, 3, 0, 3, 3, 0, 2, 3, 0, 3, 2, 2, 0, 2, 2, 0, 2, 0,
#        2, 0, 0, 0, 2, 3, 2, 3, 3, 2, 3, 0, 3, 1, 3, 0, 1, 1, 1, 0, 1, 0,
#        2, 3, 0, 0, 0, 0, 3, 1, 2, 0, 1, 1, 1, 3, 3, 2, 1, 1, 2, 0, 1, 3,
#        0, 2, 1, 3, 3, 1, 0, 2, 2, 2, 2, 0, 2, 3, 0, 2, 3, 3, 1, 2, 2, 2,
#        1, 2, 0, 0, 3, 3, 0, 3, 0, 2, 3, 3, 2, 3, 1, 0, 2, 2, 0, 1, 0, 0,
#        0, 3, 2, 0, 1, 3, 1, 0, 0, 1, 1, 1, 3, 2, 3, 0, 1, 2, 1, 3, 2, 1,
#        0, 2, 3, 2, 0, 0, 3, 2, 1, 0, 0, 1, 2, 3, 0, 2, 2, 1, 2, 0, 0, 3,
#        1, 3, 3, 2, 0, 0, 1, 3, 3, 3, 3, 0, 3, 1, 1, 0, 3, 1, 1, 3, 3, 3,
#        2, 0, 2, 0, 3, 2, 0, 1, 0, 0, 1, 2, 3, 0, 2, 3, 3, 0, 0, 0, 0, 1,
#        1, 0, 3, 0, 2, 3, 0, 3, 2, 2, 3, 0, 1, 0, 3, 0, 1, 1, 3, 3, 2, 0,
#        2, 1, 0, 0, 2, 0, 1, 0, 3, 2, 2, 1, 2, 1, 1, 1, 2, 3, 2, 2, 2, 1,
# ...

# %%
y_pred = kms.fit_predict(X)

# %%
plt.scatter(x=X[:,0],y=X[:,1],c=y_pred)

# %%
# 3.5.3 选择最优k值：轮廓系数

# %% [markdown]
# ![Screen%20Shot%202021-08-30%20at%2016.15.12.png](attachment:Screen%20Shot%202021-08-30%20at%2016.15.12.png)

# %%
silhouette_score?

# %%
for k in range(2,10):
    y_pred = KMeans(n_clusters=k).fit_predict(X)
    score = silhouette_score(X,y_pred)
    print('k值：',k,',轮廓系数值：',score)
# Out:
# k值： 2 ,轮廓系数值： 0.6831591753751677
# k值： 3 ,轮廓系数值： 0.5338917765544183
# k值： 4 ,轮廓系数值： 0.3884446956537822
# k值： 5 ,轮廓系数值： 0.3856867522222769
# k值： 6 ,轮廓系数值： 0.3704313337643406
# k值： 7 ,轮廓系数值： 0.3617118198015389
# k值： 8 ,轮廓系数值： 0.3377818343191537
# k值： 9 ,轮廓系数值： 0.33391954354412706

# %%
plt.scatter(x=X[:,0],y=X[:,1],c=KMeans(n_clusters=2).fit_predict(X))
